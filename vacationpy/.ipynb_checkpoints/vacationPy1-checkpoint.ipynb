# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data = pd.read_csv("city_data-Copy1.csv")

# %%
weather_data
# Out:
#          City Name  Latitude  Longitude  Cloudiness  Temperature  Humidity  \
# 0    Leningradskiy     69.38     178.42         100        52.05        68
# 1           Castro    -24.79     -50.01         100        66.16        82
# 2          Te Anau    -45.42     167.72          78        35.55        86
# 3          Iqaluit     63.75     -68.51          21        42.01       100
# 4       Chokurdakh     70.63     147.92         100        39.79        95
# ..             ...       ...        ...         ...          ...       ...
# 539        Slantsy     59.12      28.09          20        71.64        68
# 540        Labuhan     -6.88     112.21           6        78.46        80
# 541      Karpathos     35.51      27.21           0        79.92        60
# 542     Nouadhibou     20.93     -17.03           4        75.60        71
# 543          Bredy     52.42      60.34          58        58.05        77
#
#      Wind Speed Country
# 0          7.09      RU
# 1         10.18      BR
# 2          0.60      NZ
# 3         18.01      CA
# 4         10.33      RU
# ..          ...     ...
# 539        5.84      RU
# 540        8.28      ID
# 541       17.69      GR
# 542       26.93      MR
# 543       10.33      RU
#
# [544 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = weather_data[["Latitude", "Longitude"]].astype(float)

# Convert humidity to float and store
humidity = weather_data["Humidity"].astype(float)

# %%
# Out:
# 'jupyter nbextension enable --py gmaps'

# %%
# Out:
# 'jupyter nbextension enable --py widgetsnbextension'

# %%
# Out:
# 'jupyter notebook'

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# * Narrow down the DataFrame to find your ideal weather condition. For example:

#   * A max temperature lower than 80 degrees but higher than 70.

#   * Wind speed less than 10 mph.

#   * Zero cloudiness.

#   * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

#   * **Note:** Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Get names of indexes for which column Temperature has value more than 80
tempover80 = weather_data[ weather_data['Temperature'] > 80 ].index
# Delete these row indexes from dataFrame
weather_data.drop(tempover80 , inplace=True)

# %%
weather_data
# Out:
#          City Name  Latitude  Longitude  Cloudiness  Temperature  Humidity  \
# 0    Leningradskiy     69.38     178.42         100        52.05        68
# 1           Castro    -24.79     -50.01         100        66.16        82
# 2          Te Anau    -45.42     167.72          78        35.55        86
# 3          Iqaluit     63.75     -68.51          21        42.01       100
# 4       Chokurdakh     70.63     147.92         100        39.79        95
# ..             ...       ...        ...         ...          ...       ...
# 539        Slantsy     59.12      28.09          20        71.64        68
# 540        Labuhan     -6.88     112.21           6        78.46        80
# 541      Karpathos     35.51      27.21           0        79.92        60
# 542     Nouadhibou     20.93     -17.03           4        75.60        71
# 543          Bredy     52.42      60.34          58        58.05        77
#
#      Wind Speed Country
# 0          7.09      RU
# 1         10.18      BR
# 2          0.60      NZ
# 3         18.01      CA
# 4         10.33      RU
# ..          ...     ...
# 539        5.84      RU
# 540        8.28      ID
# 541       17.69      GR
# 542       26.93      MR
# 543       10.33      RU
#
# [410 rows x 8 columns]

# %%
# Get names of indexes for which column Temperature has value less than 70
tempunder70 = weather_data[ weather_data['Temperature'] < 70 ].index
# Delete these row indexes from dataFrame
weather_data.drop(tempunder70 , inplace=True)

# %%
weather_data
# Out:
#          City Name  Latitude  Longitude  Cloudiness  Temperature  Humidity  \
# 7           Atuona     -9.80    -139.03          34        77.58        74
# 9          Sambava    -14.27      50.17          60        73.60        76
# 14           Pātūr     20.45      76.93         100        76.10        90
# 15           Vaini    -21.20    -175.20          86        70.05        71
# 20          Avarua    -21.21    -159.78          94        70.90        78
# ..             ...       ...        ...         ...          ...       ...
# 531  Pacific Grove     36.62    -121.92          97        79.00        69
# 539        Slantsy     59.12      28.09          20        71.64        68
# 540        Labuhan     -6.88     112.21           6        78.46        80
# 541      Karpathos     35.51      27.21           0        79.92        60
# 542     Nouadhibou     20.93     -17.03           4        75.60        71
#
#      Wind Speed Country
# 7         16.42      PF
# 9         14.90      MG
# 14        11.25      IN
# 15        16.84      TO
# 20        14.50      CK
# ..          ...     ...
# 531        4.56      US
# 539        5.84      RU
# 540        8.28      ID
# 541       17.69      GR
# 542       26.93      MR
#
# [167 rows x 8 columns]

# %%
# Get names of indexes for which column Cloudiness has value greater than 0
highcloud = weather_data[ weather_data['Cloudiness'] > 0 ].index
# Delete the rows that are not these indexes from dataFrame
weather_data.drop(highcloud , inplace=True)

# %%
len(weather_data)
# Out:
# 28

# %%
# * Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.

# * Plot the hotels on top of the humidity heatmap with each pin containing the **Hotel Name**, **City**, and **Country**.

# %%
hotel_df = weather_data
hotel_df
# Out:
#              City Name  Latitude  Longitude  Cloudiness  Temperature  \
# 47             Birjand     32.87      59.22           0        75.51
# 53   Tomaszów Lubelski     50.45      23.42           0        79.00
# 99             Chapais     49.78     -74.85           0        75.99
# 108            Haftoni     38.76      48.76           0        70.50
# 129               Rome     43.21     -75.46           0        75.00
# 131             Kobryn     52.21      24.36           0        75.74
# 158         Marataizes    -21.04     -40.82           0        79.66
# 170             Torbay     47.67     -52.73           0        70.00
# 173         Villarrica    -25.75     -56.43           0        72.27
# 182           Portland     45.52    -122.68           0        75.00
# 194          Prymors'k     46.73      36.34           0        70.12
# 220             Matane     48.83     -67.52           0        70.00
# 223       Ponta do Sol     32.67     -17.10           0        73.99
# 229          Ambovombe    -25.17      46.08           0        71.49
# 237              Kumul     42.80      93.45           0        79.21
# 238        San Quintín     30.48    -115.95           0        78.26
# 244        Bay Roberts     47.60     -53.26           0        72.00
# 257  São João da Barra    -21.64     -41.05           0        79.45
# 278      Lac du Bonnet     50.25     -96.06           0        71.01
# 329            Camacha     33.08     -16.33           0        70.21
# 342          Morondava    -20.28      44.28           0        74.21
# 373            Oruzgan     32.83      66.00           0        79.36
# 428          Inhambane    -23.86      35.38           0        77.00
# 433             Wuning     29.26     120.23           0        77.22
# 439             Boueni    -12.90      45.08           0        74.70
# 461     Saint-Augustin     51.23     -58.65           0        79.29
# 529    Tsiroanomandidy    -18.77      46.03           0        70.14
# 541          Karpathos     35.51      27.21           0        79.92
#
#      Humidity  Wind Speed Country
# 47         28        8.61      IR
# 53         54        1.99      PL
# 99         42        9.69      CA
# 108        67        6.08      AZ
# 129        71        5.01      US
# 131        55        3.47      BY
# 158        64        7.56      BR
# 170        55        7.00      CA
# 173        45        4.61      PY
# 182        77        2.80      US
# 194        52        6.51      UA
# 220        51        3.78      CA
# 223        66        0.67      PT
# 229        61        4.54      MG
# 237        17        3.65      CN
# 238        57        7.94      MX
# 244       100        1.01      CA
# 257        61       10.13      BR
# 278        99        3.00      CA
# 329        79       11.48      PT
# 342        77       12.59      MG
# 373        15        3.89      AF
# 428        78       11.99      MZ
# 433        87        3.80      CN
# 439        73        4.41      YT
# 461        30        8.50      CA
# 529        22        1.12      MG
# 541        60       17.69      GR

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name'] = ""

# %%
hotel_df
# Out:
#              City Name  Latitude  Longitude  Cloudiness  Temperature  \
# 47             Birjand     32.87      59.22           0        75.51
# 53   Tomaszów Lubelski     50.45      23.42           0        79.00
# 99             Chapais     49.78     -74.85           0        75.99
# 108            Haftoni     38.76      48.76           0        70.50
# 129               Rome     43.21     -75.46           0        75.00
# 131             Kobryn     52.21      24.36           0        75.74
# 158         Marataizes    -21.04     -40.82           0        79.66
# 170             Torbay     47.67     -52.73           0        70.00
# 173         Villarrica    -25.75     -56.43           0        72.27
# 182           Portland     45.52    -122.68           0        75.00
# 194          Prymors'k     46.73      36.34           0        70.12
# 220             Matane     48.83     -67.52           0        70.00
# 223       Ponta do Sol     32.67     -17.10           0        73.99
# 229          Ambovombe    -25.17      46.08           0        71.49
# 237              Kumul     42.80      93.45           0        79.21
# 238        San Quintín     30.48    -115.95           0        78.26
# 244        Bay Roberts     47.60     -53.26           0        72.00
# 257  São João da Barra    -21.64     -41.05           0        79.45
# 278      Lac du Bonnet     50.25     -96.06           0        71.01
# 329            Camacha     33.08     -16.33           0        70.21
# 342          Morondava    -20.28      44.28           0        74.21
# 373            Oruzgan     32.83      66.00           0        79.36
# 428          Inhambane    -23.86      35.38           0        77.00
# 433             Wuning     29.26     120.23           0        77.22
# 439             Boueni    -12.90      45.08           0        74.70
# 461     Saint-Augustin     51.23     -58.65           0        79.29
# 529    Tsiroanomandidy    -18.77      46.03           0        70.14
# 541          Karpathos     35.51      27.21           0        79.92
#
#      Humidity  Wind Speed Country Hotel Name
# 47         28        8.61      IR
# 53         54        1.99      PL
# 99         42        9.69      CA
# 108        67        6.08      AZ
# 129        71        5.01      US
# 131        55        3.47      BY
# 158        64        7.56      BR
# 170        55        7.00      CA
# 173        45        4.61      PY
# 182        77        2.80      US
# 194        52        6.51      UA
# 220        51        3.78      CA
# 223        66        0.67      PT
# 229        61        4.54      MG
# 237        17        3.65      CN
# 238        57        7.94      MX
# 244       100        1.01      CA
# 257        61       10.13      BR
# 278        99        3.00      CA
# 329        79       11.48      PT
# 342        77       12.59      MG
# 373        15        3.89      AF
# 428        78       11.99      MZ
# 433        87        3.80      CN
# 439        73        4.41      YT
# 461        30        8.50      CA
# 529        22        1.12      MG
# 541        60       17.69      GR

# %%
# concatenating the columns 
hotel_df['Coordinates'] = hotel_df['Latitude'].map(str) + ',' + hotel_df['Longitude'].map(str) 
print(hotel_df)
# Out:
#              City Name  Latitude  Longitude  Cloudiness  Temperature  \
# 47             Birjand     32.87      59.22           0        75.51
# 53   Tomaszów Lubelski     50.45      23.42           0        79.00
# 99             Chapais     49.78     -74.85           0        75.99
# 108            Haftoni     38.76      48.76           0        70.50
# 129               Rome     43.21     -75.46           0        75.00
# 131             Kobryn     52.21      24.36           0        75.74
# 158         Marataizes    -21.04     -40.82           0        79.66
# 170             Torbay     47.67     -52.73           0        70.00
# 173         Villarrica    -25.75     -56.43           0        72.27
# 182           Portland     45.52    -122.68           0        75.00
# 194          Prymors'k     46.73      36.34           0        70.12
# 220             Matane     48.83     -67.52           0        70.00
# 223       Ponta do Sol     32.67     -17.10           0        73.99
# 229          Ambovombe    -25.17      46.08           0        71.49
# 237              Kumul     42.80      93.45           0        79.21
# 238        San Quintín     30.48    -115.95           0        78.26
# 244        Bay Roberts     47.60     -53.26           0        72.00
# 257  São João da Barra    -21.64     -41.05           0        79.45
# 278      Lac du Bonnet     50.25     -96.06           0        71.01
# 329            Camacha     33.08     -16.33           0        70.21
# 342          Morondava    -20.28      44.28           0        74.21
# 373            Oruzgan     32.83      66.00           0        79.36
# 428          Inhambane    -23.86      35.38           0        77.00
# 433             Wuning     29.26     120.23           0        77.22
# 439             Boueni    -12.90      45.08           0        74.70
# 461     Saint-Augustin     51.23     -58.65           0        79.29
# 529    Tsiroanomandidy    -18.77      46.03           0        70.14
# 541          Karpathos     35.51      27.21           0        79.92
#
#      Humidity  Wind Speed Country Hotel Name    Coordinates
# 47         28        8.61      IR               32.87,59.22
# 53         54        1.99      PL               50.45,23.42
# 99         42        9.69      CA              49.78,-74.85
# 108        67        6.08      AZ               38.76,48.76
# 129        71        5.01      US              43.21,-75.46
# 131        55        3.47      BY               52.21,24.36
# 158        64        7.56      BR             -21.04,-40.82
# 170        55        7.00      CA              47.67,-52.73
# 173        45        4.61      PY             -25.75,-56.43
# 182        77        2.80      US             45.52,-122.68
# 194        52        6.51      UA               46.73,36.34
# 220        51        3.78      CA              48.83,-67.52
# 223        66        0.67      PT               32.67,-17.1
# 229        61        4.54      MG              -25.17,46.08
# 237        17        3.65      CN                42.8,93.45
# 238        57        7.94      MX             30.48,-115.95
# 244       100        1.01      CA               47.6,-53.26
# 257        61       10.13      BR             -21.64,-41.05
# 278        99        3.00      CA              50.25,-96.06
# 329        79       11.48      PT              33.08,-16.33
# 342        77       12.59      MG              -20.28,44.28
# 373        15        3.89      AF                32.83,66.0
# 428        78       11.99      MZ              -23.86,35.38
# 433        87        3.80      CN              29.26,120.23
# 439        73        4.41      YT               -12.9,45.08
# 461        30        8.50      CA              51.23,-58.65
# 529        22        1.12      MG              -18.77,46.03
# 541        60       17.69      GR               35.51,27.21

# %%
# find the closest hotel to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():

    # get coords from df
    location = row['Coordinates']

    # add location to params dict
    params['location'] = location

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {location}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {index} is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 47: 32.87,59.22.
# Closest hotel to 47 is مجتمع خدماتی رفاهی غدیر.
# ------------
# Retrieving Results for Index 53: 50.45,23.42.
# Closest hotel to 53 is ibis Styles Tomaszow Lubelski.
# ------------
# Retrieving Results for Index 99: 49.78,-74.85.
# Closest hotel to 99 is Motel Clossi.
# ------------
# Retrieving Results for Index 108: 38.76,48.76.
# Closest hotel to 108 is Lankaran Springs Wellness Resort.
# ------------
# Retrieving Results for Index 129: 43.21,-75.46.
# Closest hotel to 129 is Quality Inn Rome- Verona.
# ------------
# Retrieving Results for Index 131: 52.21,24.36.
# Closest hotel to 131 is Suvorov-Apartamenty.
# ------------
# Retrieving Results for Index 158: -21.04,-40.82.
# Closest hotel to 158 is Edificio Carone.
# ------------
# Retrieving Results for Index 170: 47.67,-52.73.
# Closest hotel to 170 is Gallows Cove.
# ------------
# Retrieving Results for Index 173: -25.75,-56.43.
# Closest hotel to 173 is Hotel Restaurant Paraiso.
# ------------
# Retrieving Results for Index 182: 45.52,-122.68.
# Closest hotel to 182 is Downtown Luxury Suites by Barsala.
# ------------
# Retrieving Results for Index 194: 46.73,36.34.
# Closest hotel to 194 is Relax.
# ------------
# Retrieving Results for Index 220: 48.83,-67.52.
# Closest hotel to 220 is Gite Des Iles.
# ------------
# Retrieving Results for Index 223: 32.67,-17.1.
# Closest hotel to 223 is Estalagem Da Ponta Do Sol.
# ------------
# Retrieving Results for Index 229: -25.17,46.08.
# Closest hotel to 229 is MONJA Talilisoa.
# ------------
# Retrieving Results for Index 237: 42.8,93.45.
# Closest hotel to 237 is Laoyutang Resort.
# ------------
# Retrieving Results for Index 238: 30.48,-115.95.
# Closest hotel to 238 is Hotel Jardines Baja.
# ------------
# Retrieving Results for Index 244: 47.6,-53.26.
# Closest hotel to 244 is Klondyke Hotel.
# ------------
# Retrieving Results for Index 257: -21.64,-41.05.
# Closest hotel to 257 is Pousada Porto De Canoas.
# ------------
# Retrieving Results for Index 278: 50.25,-96.06.
# Closest hotel to 278 is The Lakeview Inn.
# ------------
# Retrieving Results for Index 329: 33.08,-16.33.
# Closest hotel to 329 is Porto Santo Apartments.
# ------------
# Retrieving Results for Index 342: -20.28,44.28.
# Closest hotel to 342 is eden rock hotel.
# ------------
# Retrieving Results for Index 373: 32.83,66.0.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 428: -23.86,35.38.
# Closest hotel to 428 is Hotel Casa Do Capitão.
# ------------
# Retrieving Results for Index 433: 29.26,120.23.
# Closest hotel to 433 is Nanyang Hotel Bathroom.
# ------------
# Retrieving Results for Index 439: -12.9,45.08.
# Closest hotel to 439 is Auberge bouloulou( inter djasmire ).
# ------------
# Retrieving Results for Index 461: 51.23,-58.65.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 529: -18.77,46.03.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 541: 35.51,27.21.
# Closest hotel to 541 is Atlantis Hotel.
# ------------

# %%
hotel_df
# Out:
#              City Name  Latitude  Longitude  Cloudiness  Temperature  \
# 47             Birjand     32.87      59.22           0        75.51
# 53   Tomaszów Lubelski     50.45      23.42           0        79.00
# 99             Chapais     49.78     -74.85           0        75.99
# 108            Haftoni     38.76      48.76           0        70.50
# 129               Rome     43.21     -75.46           0        75.00
# 131             Kobryn     52.21      24.36           0        75.74
# 158         Marataizes    -21.04     -40.82           0        79.66
# 170             Torbay     47.67     -52.73           0        70.00
# 173         Villarrica    -25.75     -56.43           0        72.27
# 182           Portland     45.52    -122.68           0        75.00
# 194          Prymors'k     46.73      36.34           0        70.12
# 220             Matane     48.83     -67.52           0        70.00
# 223       Ponta do Sol     32.67     -17.10           0        73.99
# 229          Ambovombe    -25.17      46.08           0        71.49
# 237              Kumul     42.80      93.45           0        79.21
# 238        San Quintín     30.48    -115.95           0        78.26
# 244        Bay Roberts     47.60     -53.26           0        72.00
# 257  São João da Barra    -21.64     -41.05           0        79.45
# 278      Lac du Bonnet     50.25     -96.06           0        71.01
# 329            Camacha     33.08     -16.33           0        70.21
# 342          Morondava    -20.28      44.28           0        74.21
# 373            Oruzgan     32.83      66.00           0        79.36
# 428          Inhambane    -23.86      35.38           0        77.00
# 433             Wuning     29.26     120.23           0        77.22
# 439             Boueni    -12.90      45.08           0        74.70
# 461     Saint-Augustin     51.23     -58.65           0        79.29
# 529    Tsiroanomandidy    -18.77      46.03           0        70.14
# 541          Karpathos     35.51      27.21           0        79.92
#
#      Humidity  Wind Speed Country                           Hotel Name  \
# 47         28        8.61      IR              مجتمع خدماتی رفاهی غدیر
# 53         54        1.99      PL        ibis Styles Tomaszow Lubelski
# 99         42        9.69      CA                         Motel Clossi
# 108        67        6.08      AZ     Lankaran Springs Wellness Resort
# 129        71        5.01      US             Quality Inn Rome- Verona
# 131        55        3.47      BY                  Suvorov-Apartamenty
# 158        64        7.56      BR                      Edificio Carone
# 170        55        7.00      CA                         Gallows Cove
# 173        45        4.61      PY             Hotel Restaurant Paraiso
# 182        77        2.80      US    Downtown Luxury Suites by Barsala
# 194        52        6.51      UA                                Relax
# 220        51        3.78      CA                        Gite Des Iles
# 223        66        0.67      PT            Estalagem Da Ponta Do Sol
# 229        61        4.54      MG                      MONJA Talilisoa
# 237        17        3.65      CN                     Laoyutang Resort
# 238        57        7.94      MX                  Hotel Jardines Baja
# 244       100        1.01      CA                       Klondyke Hotel
# 257        61       10.13      BR              Pousada Porto De Canoas
# 278        99        3.00      CA                     The Lakeview Inn
# 329        79       11.48      PT               Porto Santo Apartments
# 342        77       12.59      MG                      eden rock hotel
# 373        15        3.89      AF
# 428        78       11.99      MZ                Hotel Casa Do Capitão
# 433        87        3.80      CN               Nanyang Hotel Bathroom
# 439        73        4.41      YT  Auberge bouloulou( inter djasmire )
# 461        30        8.50      CA
# 529        22        1.12      MG
# 541        60       17.69      GR                       Atlantis Hotel
#
#        Coordinates
# 47     32.87,59.22
# 53     50.45,23.42
# 99    49.78,-74.85
# 108    38.76,48.76
# 129   43.21,-75.46
# 131    52.21,24.36
# 158  -21.04,-40.82
# 170   47.67,-52.73
# 173  -25.75,-56.43
# 182  45.52,-122.68
# 194    46.73,36.34
# 220   48.83,-67.52
# 223    32.67,-17.1
# 229   -25.17,46.08
# 237     42.8,93.45
# 238  30.48,-115.95
# 244    47.6,-53.26
# 257  -21.64,-41.05
# 278   50.25,-96.06
# 329   33.08,-16.33
# 342   -20.28,44.28
# 373     32.83,66.0
# 428   -23.86,35.38
# 433   29.26,120.23
# 439    -12.9,45.08
# 461   51.23,-58.65
# 529   -18.77,46.03
# 541    35.51,27.21

# %%
hotel_df.reset_index(drop=True)
# Out:
#             City Name  Latitude  Longitude  Cloudiness  Temperature  Humidity  \
# 0             Birjand     32.87      59.22           0        75.51        28
# 1   Tomaszów Lubelski     50.45      23.42           0        79.00        54
# 2             Chapais     49.78     -74.85           0        75.99        42
# 3             Haftoni     38.76      48.76           0        70.50        67
# 4                Rome     43.21     -75.46           0        75.00        71
# 5              Kobryn     52.21      24.36           0        75.74        55
# 6          Marataizes    -21.04     -40.82           0        79.66        64
# 7              Torbay     47.67     -52.73           0        70.00        55
# 8          Villarrica    -25.75     -56.43           0        72.27        45
# 9            Portland     45.52    -122.68           0        75.00        77
# 10          Prymors'k     46.73      36.34           0        70.12        52
# 11             Matane     48.83     -67.52           0        70.00        51
# 12       Ponta do Sol     32.67     -17.10           0        73.99        66
# 13          Ambovombe    -25.17      46.08           0        71.49        61
# 14              Kumul     42.80      93.45           0        79.21        17
# 15        San Quintín     30.48    -115.95           0        78.26        57
# 16        Bay Roberts     47.60     -53.26           0        72.00       100
# 17  São João da Barra    -21.64     -41.05           0        79.45        61
# 18      Lac du Bonnet     50.25     -96.06           0        71.01        99
# 19            Camacha     33.08     -16.33           0        70.21        79
# 20          Morondava    -20.28      44.28           0        74.21        77
# 21            Oruzgan     32.83      66.00           0        79.36        15
# 22          Inhambane    -23.86      35.38           0        77.00        78
# 23             Wuning     29.26     120.23           0        77.22        87
# 24             Boueni    -12.90      45.08           0        74.70        73
# 25     Saint-Augustin     51.23     -58.65           0        79.29        30
# 26    Tsiroanomandidy    -18.77      46.03           0        70.14        22
# 27          Karpathos     35.51      27.21           0        79.92        60
#
#     Wind Speed Country                           Hotel Name    Coordinates
# 0         8.61      IR              مجتمع خدماتی رفاهی غدیر    32.87,59.22
# 1         1.99      PL        ibis Styles Tomaszow Lubelski    50.45,23.42
# 2         9.69      CA                         Motel Clossi   49.78,-74.85
# 3         6.08      AZ     Lankaran Springs Wellness Resort    38.76,48.76
# 4         5.01      US             Quality Inn Rome- Verona   43.21,-75.46
# 5         3.47      BY                  Suvorov-Apartamenty    52.21,24.36
# 6         7.56      BR                      Edificio Carone  -21.04,-40.82
# 7         7.00      CA                         Gallows Cove   47.67,-52.73
# 8         4.61      PY             Hotel Restaurant Paraiso  -25.75,-56.43
# 9         2.80      US    Downtown Luxury Suites by Barsala  45.52,-122.68
# 10        6.51      UA                                Relax    46.73,36.34
# 11        3.78      CA                        Gite Des Iles   48.83,-67.52
# 12        0.67      PT            Estalagem Da Ponta Do Sol    32.67,-17.1
# 13        4.54      MG                      MONJA Talilisoa   -25.17,46.08
# 14        3.65      CN                     Laoyutang Resort     42.8,93.45
# 15        7.94      MX                  Hotel Jardines Baja  30.48,-115.95
# 16        1.01      CA                       Klondyke Hotel    47.6,-53.26
# 17       10.13      BR              Pousada Porto De Canoas  -21.64,-41.05
# 18        3.00      CA                     The Lakeview Inn   50.25,-96.06
# 19       11.48      PT               Porto Santo Apartments   33.08,-16.33
# 20       12.59      MG                      eden rock hotel   -20.28,44.28
# 21        3.89      AF                                          32.83,66.0
# 22       11.99      MZ                Hotel Casa Do Capitão   -23.86,35.38
# 23        3.80      CN               Nanyang Hotel Bathroom   29.26,120.23
# 24        4.41      YT  Auberge bouloulou( inter djasmire )    -12.9,45.08
# 25        8.50      CA                                        51.23,-58.65
# 26        1.12      MG                                        -18.77,46.03
# 27       17.69      GR                       Atlantis Hotel    35.51,27.21

# %%
new_hotel_df = (hotel_df.drop(hotel_df.index[[0, 21, 25,26]]))
new_hotel_df
# Out:
#              City Name  Latitude  Longitude  Cloudiness  Temperature  \
# 53   Tomaszów Lubelski     50.45      23.42           0        79.00
# 99             Chapais     49.78     -74.85           0        75.99
# 108            Haftoni     38.76      48.76           0        70.50
# 129               Rome     43.21     -75.46           0        75.00
# 131             Kobryn     52.21      24.36           0        75.74
# 158         Marataizes    -21.04     -40.82           0        79.66
# 170             Torbay     47.67     -52.73           0        70.00
# 173         Villarrica    -25.75     -56.43           0        72.27
# 182           Portland     45.52    -122.68           0        75.00
# 194          Prymors'k     46.73      36.34           0        70.12
# 220             Matane     48.83     -67.52           0        70.00
# 223       Ponta do Sol     32.67     -17.10           0        73.99
# 229          Ambovombe    -25.17      46.08           0        71.49
# 237              Kumul     42.80      93.45           0        79.21
# 238        San Quintín     30.48    -115.95           0        78.26
# 244        Bay Roberts     47.60     -53.26           0        72.00
# 257  São João da Barra    -21.64     -41.05           0        79.45
# 278      Lac du Bonnet     50.25     -96.06           0        71.01
# 329            Camacha     33.08     -16.33           0        70.21
# 342          Morondava    -20.28      44.28           0        74.21
# 428          Inhambane    -23.86      35.38           0        77.00
# 433             Wuning     29.26     120.23           0        77.22
# 439             Boueni    -12.90      45.08           0        74.70
# 541          Karpathos     35.51      27.21           0        79.92
#
#      Humidity  Wind Speed Country                           Hotel Name  \
# 53         54        1.99      PL        ibis Styles Tomaszow Lubelski
# 99         42        9.69      CA                         Motel Clossi
# 108        67        6.08      AZ     Lankaran Springs Wellness Resort
# 129        71        5.01      US             Quality Inn Rome- Verona
# 131        55        3.47      BY                  Suvorov-Apartamenty
# 158        64        7.56      BR                      Edificio Carone
# 170        55        7.00      CA                         Gallows Cove
# 173        45        4.61      PY             Hotel Restaurant Paraiso
# 182        77        2.80      US    Downtown Luxury Suites by Barsala
# 194        52        6.51      UA                                Relax
# 220        51        3.78      CA                        Gite Des Iles
# 223        66        0.67      PT            Estalagem Da Ponta Do Sol
# 229        61        4.54      MG                      MONJA Talilisoa
# 237        17        3.65      CN                     Laoyutang Resort
# 238        57        7.94      MX                  Hotel Jardines Baja
# 244       100        1.01      CA                       Klondyke Hotel
# 257        61       10.13      BR              Pousada Porto De Canoas
# 278        99        3.00      CA                     The Lakeview Inn
# 329        79       11.48      PT               Porto Santo Apartments
# 342        77       12.59      MG                      eden rock hotel
# 428        78       11.99      MZ                Hotel Casa Do Capitão
# 433        87        3.80      CN               Nanyang Hotel Bathroom
# 439        73        4.41      YT  Auberge bouloulou( inter djasmire )
# 541        60       17.69      GR                       Atlantis Hotel
#
#        Coordinates
# 53     50.45,23.42
# 99    49.78,-74.85
# 108    38.76,48.76
# 129   43.21,-75.46
# 131    52.21,24.36
# 158  -21.04,-40.82
# 170   47.67,-52.73
# 173  -25.75,-56.43
# 182  45.52,-122.68
# 194    46.73,36.34
# 220   48.83,-67.52
# 223    32.67,-17.1
# 229   -25.17,46.08
# 237     42.8,93.45
# 238  30.48,-115.95
# 244    47.6,-53.26
# 257  -21.64,-41.05
# 278   50.25,-96.06
# 329   33.08,-16.33
# 342   -20.28,44.28
# 428   -23.86,35.38
# 433   29.26,120.23
# 439    -12.9,45.08
# 541    35.51,27.21

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City Name}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in new_hotel_df.iterrows()]
locations = new_hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
)


fig = gmaps.figure()
fig.add_layer(marker_layer)

fig
# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
